# %% [markdown]
# ## Notebook ejemplo para Visión por Ordenador
#
# Jupyter notebook es una gran herramienta para explicar los fundamentos de visión por ordenador y el tratamiento de imágenes.
#
# En IPython existen muchas librerías para el procesamiento de imágenes. Éstas ofrecen al programador funcionalidades que abstraen la complejidad de los algoritmos que utilizan.
#
# Para el objetivo docente de la asignatura estas librerías nos limita estudiar y comprender los algoritmos de procesamiento de imágenes. De cualquier forma con IPython se pueden realizar procesameinto de imágenessin usar librerías y mostrando el proceso realizado.
#
# Librerías de uso básico a usar (MatPlot,Numpy)
#
# - http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.hist
# - http://www.scipy-lectures.org/advanced/image_processing/
# - http://relopezbriega.github.io/blog/2015/06/27/probabilidad-y-estadistica-con-python/
#
# Librerías de imagenes que se **deben evitar** (Pillow PIL,Open CV)
#
# - http://pillow.readthedocs.io/en/3.3.x/handbook/tutorial.html

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from scipy import misc

# %% [markdown]
# Cargamos una imagen en formato bmp desde disco

# %%
from PIL import Image
img= Image.open(r'animal.tfe.bmp')
#plt.imshow(img,cmap='gray',vmin=0,vmax=255)
plt.imshow(img)

# %%
type(img)
# Out:
# PIL.BmpImagePlugin.BmpImageFile

# %% [markdown]
# Una imagen de 200 x 300 pixel en los 3 canales

# %%
img2= misc.imread('animal.tfe.bmp')
#misc.imsave('img.bmp', img)
type(img2)
img2.shape
# Out:
# 0

# %% [markdown]
# La imagen está en escala de grises. El mismo valor en los tres canales.

# %%
print (img2[3,4,:])
# Out:
# [123 123 123]

# %%
plt.imshow(img2)

# %%
plt.hist(img2.flatten())
# Out:
# (array([ 48495.,  11088.,  13395.,  10608.,  23061.,  20706.,  22896.,
#          29094.,   8838.,   3819.]),
#  array([   0.,   25.,   50.,   75.,  100.,  125.,  150.,  175.,  200.,
#          225.,  250.]),
#  <a list of 10 Patch objects>)

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

def my_histogram(x):
    img3=img2+x
    plt.hist(img3.flatten())
    return

interact(my_histogram, x=(0,255));
